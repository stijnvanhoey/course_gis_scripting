# %%
from waterinfo_example_2 import request_waterinfo_timeseries, plot_waterheight_timeseries
# %matplotlib inline

# %%
data = request_waterinfo_timeseries("0162939042", period="P3D")

# %%
fig, ax = plot_waterheight_timeseries(data, moving_windows=[1, 3, 6])
